# %%
import GPflow
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
N = 12
X = np.random.rand(N,1)
Y = np.sin(12*X) + 0.66*np.cos(25*X) + np.random.randn(N,1)*0.1 + 3+np.random.rand(N,1)+np.random.rand(N,1)
plt.plot(X, Y, 'kx', mew=2)

# %%
k = GPflow.kernels.Linear(1)#GPflow.kernels.Matern52(1, lengthscales=0.3)
m = GPflow.gpr.GPR(X, Y, kern=k)
m.likelihood.variance = 0.01

# %%
def plot(m):
    xx = np.linspace(-0.1, 1.1, 100)[:,None]
    mean, var = m.predict_y(xx)
    plt.figure(figsize=(12, 6))
    plt.plot(X, Y, 'kx', mew=2)
    plt.plot(xx,
            mean, 'b', lw=2)
    plt.fill_between(xx[:,0], mean[:,0] - 2*np.sqrt(var[:,0]), mean[:,0] + 2*np.sqrt(var[:,0]), color='blue', alpha=0.2)
    plt.xlim(-0.1, 1.1)
plot(m)

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>name.likelihood.variance</td><td>[ 0.01]</td><td>None</td><td>+ve</td></tr><tr><td>name.kern.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>name.kern.lengthscales</td><td>[ 0.3]</td><td>None</td><td>+ve</td></tr></table>

# %%
    xx = np.linspace(-0.1, 1.1, 100)[:,None]
    mean, var = m.predict_y(xx)

# %%
import tensorflow as tf

class Brownian(GPflow.kernels.Kern):
    def __init__(self):
        GPflow.kernels.Kern.__init__(self, input_dim=1, active_dims=[0])
        self.variance = GPflow.param.Param(1.0, transform=GPflow.transforms.positive)
        
    def K(self, X, X2=None):
        if X2 is None:
            X2 = X
        return self.variance * tf.minimum(X, tf.transpose(X2))
    
    def Kdiag(self, X):
        return self.variance * tf.reshape(X, (-1,))
    
X = np.random.rand(5, 1)
Y = np.sin(X*6) + np.random.randn(*X.shape)*0.001


k1 = Brownian()
k2 = GPflow.kernels.Constant(1)
k = k1 + k2

m = GPflow.gpr.GPR(X, Y, kern=k)
m.optimize()

xx = np.linspace(0, 1.1, 100).reshape(100, 1)
mean, var = m.predict_y(xx)
plt.plot(X, Y, 'kx', mew=2)
line, = plt.plot(xx, mean, lw=2)
_ = plt.fill_between(xx[:,0], mean[:,0] - 2*np.sqrt(var[:,0]), mean[:,0] + 2*np.sqrt(var[:,0]), color=line.get_color(), alpha=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-6fbf33576f37> in <module>()
#      21
#      22 m = GPflow.gpr.GPR(X, Y, kern=k)
# ---> 23 m.optimize()
#      24
#      25 xx = np.linspace(0, 1.1, 100).reshape(100, 1)
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/model.pyc in optimize(self, method, tol, callback, maxiter, **kw)
#     223
#     224         if type(method) is str:
# --> 225             return self._optimize_np(method, tol, callback, maxiter, **kw)
#     226         else:
#     227             return self._optimize_tf(method, callback, maxiter, **kw)
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/model.pyc in _optimize_np(self, method, tol, callback, maxiter, **kw)
#     284         """
#     285         if self._needs_recompile:
# --> 286             self._compile()
#     287
#     288         options = dict(disp=settings.verbosity.optimisation_verb, maxiter=maxiter)
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/model.pyc in _compile(self, optimizer)
#     133             self.make_tf_array(self._free_vars)
#     134             with self.tf_mode():
# --> 135                 f = self.build_likelihood() + self.build_prior()
#     136                 g, = tf.gradients(f, self._free_vars)
#     137
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/scoping.pyc in runnable(*args, **kwargs)
#      39         def runnable(*args, **kwargs):
#      40             with tf.name_scope(self.name):
# ---> 41                 return f(*args, **kwargs)
#      42         return runnable
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/gpr.pyc in build_likelihood(self)
#      57
#      58         """
# ---> 59         K = self.kern.K(self.X) + tf.eye(tf.shape(self.X)[0], dtype=float_type) * self.likelihood.variance
#      60         L = tf.cholesky(K)
#      61         m = self.mean_function(self.X)
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/scoping.pyc in runnable(*args, **kwargs)
#      39         def runnable(*args, **kwargs):
#      40             with tf.name_scope(self.name):
# ---> 41                 return f(*args, **kwargs)
#      42         return runnable
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/kernels.pyc in K(self, X, X2, presliced)
#     761 class Add(Combination):
#     762     def K(self, X, X2=None, presliced=False):
# --> 763         return reduce(tf.add, [k.K(X, X2) for k in self.kern_list])
#     764
#     765     def Kdiag(self, X, presliced=False):
#
# /Users/dna/miniconda2/lib/python2.7/site-packages/GPflow-0.3.5-py2.7.egg/GPflow/scoping.pyc in runnable(*args, **kwargs)
#      39         def runnable(*args, **kwargs):
#      40             with tf.name_scope(self.name):
# ---> 41                 return f(*args, **kwargs)
#      42         return runnable
#
# <ipython-input-36-6fbf33576f37> in K(self, X, X2)
#       7         if X2 is None:
#       8             X2 = X
# ----> 9         return self.variance * tf.minimum(X, tf.transpose(X2))
#      10
#      11     def Kdiag(self, X):
#
# NameError: global name 'tf' is not defined
